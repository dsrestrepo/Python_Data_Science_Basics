# %% [markdown]
# # This is a text cell
#
# <h3> You can use some html tags... <h3>
#
# ### You can use some html tags...
#
# You can create an unorder list:
#
# *   List item
# *   List item
#
# Or an order list:
# 1.   List item
# 2.   List item
#
#
# Or even equations 😯:
#
# E.g. the mean:
#
# $$
# {\displaystyle A={\frac {1}{n}}\sum _{i=1}^{n}a_{i}={\frac {a_{1}+a_{2}+\cdots +a_{n}}{n}}}
# $$

# %% [markdown]
# # Comments

# %%
# This is a python comment

''' 
This is a python multi-line comment.
Use it to documment your functions
'''

print('You can also prin text in the console using print function...')
# Out:
# You can also prin text in the console using print function...

# %% [markdown]
# # Variables

# %%
# Numeric variables
int_variable = 1
real_variable = -12342.41

# String
string_variable = "This is a String"
string_Variable_2 = '12214'

# Boolean
boolean_var = True
boolean_var_2 = False

# List
list_variable = [1, 4, 6, -30]
list_variable_2 = [1, 4, 6, -30, 'hello', -324.54, True, 'Hi']

# Dictionary
dictionary = {
    'id': [1, 2, 3, 4, 5, 6, 7],
    'age': [14, 23, 33, 14, 25, 16, 17],
    'name': ['Raul', 'David', 'Laura', 'Lucia', 'Daniel', 'Roberto', 'Leo']
}

print("You can also print variables by concatenating them using ',' like the dictionary: \n", dictionary)
# Out:
# You can also print variables by concatenating them using ',' like the dictionary:
#  {'id': [1, 2, 3, 4, 5, 6, 7], 'age': [14, 23, 33, 14, 25, 16, 17], 'name': ['Raul', 'David', 'Laura', 'Lucia', 'Daniel', 'Roberto', 'Leo']}

# %%
list_variable_2[4]
# Out:
# 'hello'

# %%
dictionary["name"][1]

dictionary.keys()
# Out:
# dict_keys(['id', 'age', 'name'])

# %% [markdown]
# # Conditionals

# %%
num1 = 5
num2 = 10

if num1 > num2:
  print(num1, 'es mayor que ', num2)
elif (num1 == num2):
  print(num1, 'es igual que ', num2)
else:
  print(num1, 'es menor que ', num2)
# Out:
# 5 es menor que  10

# %% [markdown]
# # loops

# %% [markdown]
# ### For Loop

# %%
names = ['Raul', 'David', 'Laura', 'Lucia', 'Daniel', 'Roberto', 'Leo']

# for loop in a list
for name in names:
  print(name)

print('')

# For loop in a range:
for i in range(len(names)):
  name = names[i]
  print(name)
# Out:
# Raul
# David
# Laura
# Lucia
# Daniel
# Roberto
# Leo
#
# Raul
# David
# Laura
# Lucia
# Daniel
# Roberto
# Leo

# %% [markdown]
# ### While loop

# %%
i = int(input('say a value: '))
arr = []

while i > 0 and i < 10:
  item = input('say an item: ')
  arr.append(item)

  i-=1

print('The list with items is: ', arr)
# Out:
# say i value: 5
# say an item: 3
# say an item: 4
# say an item: 6
# say an item: 7
# say an item: 8
# The list with items is:  ['3', '4', '6', '7', '8']

# %%
size = int(input('say a value: '))
arr = []

for i in range(size):
  item = input('say an item: ')
  arr.append(item)
  
print('The list with items is: ', arr)
# Out:
# say a value: 4
# say an item: 1.80
# say an item: 34
# say an item: 34
# say an item: 45
# The list with items is:  ['1.80', '34', '34', '45']

# %% [markdown]
# # Functions

# %%
def put_a_number(arr):
  number = input('Give a number: ')

  try:
    number = int(number)
  except:
    print('Input should be of numeric type')
    return False
  
  arr.append(number)
  return arr, number

# %%
arr = list()
# arr = []
put_a_number(arr)
arr
# Out:
# Give a number: -15.67
# Input should be of numeric type
# []

# %% [markdown]
# # Class

# %%
class Person:
  def __init__(self, name, id, age):
    self.name = name
    self.id = id
    self.age = age

  def say_hi(self):
    print(f'Hello my name is {self.name}')

# %%
david = Person(name='David', id=123324, age=23)

# %%
david.say_hi()
# Out:
# Hello my name is David

# %% [markdown]
# # Example Calculator

# %%
def get_a_number():
  number = input('Give a number: ')

  try:
    number = int(number)
    return number
  except:
    print('Input should be of numeric type')
    return False

# %%
number1 = get_a_number()
number2 = get_a_number()

if number1 and number2:
  operation = input('Do you want to do a sum? y/n: ')
  if operation.lower() in ['yeah', 'y', 'yep', 'yes']:
    result = number1 + number2
  else:
    result =  number1 - number2

  print(f'The result is: {result}')
else:
  ('Error. Try again')
# Out:
# Give a number: 5
# Give a number: 7
# Do you want to do a sum? y/n: Yeah
# The result is: 12

# %% [markdown]
# # Example IMC
#
# $$
# BMI = \frac{weight [kg]} {(height [m])^ 2 }
# $$

# %%
class Person:
  def __init__(self, name, weight, height):
    self.name = name
    self.weight = weight
    self.height = height
    self.bmi = weight / (height ** 2)

  def get_bmi(self):
    self.bmi = self.weight / (self.height ** 2)
    print(f'The bmi of {self.name} is: {self.bmi}%')

# %%
David = Person('David', 74, 1.80)
David.get_bmi()
# Out:
# The bmi of David is: 22.839506172839506%

# %%
David.height = 1.70
print(David.bmi)
print(David.get_bmi())
# Out:
# 22.839506172839506
# The bmi of David is: 25.605536332179934%
# None
